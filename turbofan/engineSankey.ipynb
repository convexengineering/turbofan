# %%
# Imports 
"SP Implementation of the TASOPT engine model"
from gpkit import Model, Variable, SignomialsEnabled, units, Vectorize, SignomialEquality
from gpkit.constraints.tight import Tight as TCS
from gpkit.small_scripts import mag
from gpkit.interactive.sankey import Sankey
import numpy as np

#import substitution files
from get_737800_subs import get_737800_subs
from get_d82_subs import get_D82_subs
from cfm56_subs import get_cfm56_subs
from get_ge90_subs import get_ge90_subs

# importing turbofan
from engine_validation import *

# importing

# %%
# Running standard test
"""
Test the cfm56 engine model
"""
with Vectorize(2):
    state = TestState()

Engine.Ttmax = True
Engine.OPRmax = True
engine = Engine(0, True, 2, state, 0)

mission = TestMissionCFM(engine)

# %%
substitutions = get_cfm56_subs()
substitutions.update({'T_{t_{4.1_{max}}}':1400})
substitutions.update({'OPR_{max}':32})
del substitutions['\\pi_{hc_D}']
del substitutions['\\pi_{lc_D}']
del substitutions['\\pi_{f_D}']
print substitutions
# Out:
# {'\\pi_{fn}': 0.98, 'T_{t_{4.1_{max}}}': 1400, '\\pi_{tn}': 0.98, 'hold_{4a}': 1.001644228125, '\\alpha_{max}': 5.105, 'C_{p_{c}}': 1216, 'C_{p_{t1}}': 1280, 'C_{p_{t2}}': 1184, 'h_{f}': 40.8, 'M_{takeoff}': 0.9556, '\\eta_{B}': 0.9827, 'r_{uc}': 0.01, 'OPR_{max}': 32, '\\pi_{b}': 0.94, '\\pi_{d}': 0.98, 'T_{t_f}': 435, 'HTR_{lpc_{SUB}}': 0.64, 'HTR_{f_{SUB}}': 0.91, 'G_{f}': 1, '\\eta_{HPshaft}': 0.97, '\\alpha_{OD}': 5.105, '\\eta_{LPshaft}': 0.97, 'T_{ref}': 288.15, '\\alpha_c': 0.19036, 'P_{ref}': 101.325}

# %%
m = Model((10*engine.engineP.thrustP['TSFC'][0]+engine.engineP.thrustP['TSFC'][1]), [engine, mission], substitutions)
m.substitutions.update(substitutions)
sol = m.localsolve(verbosity = 2)
# Out:
# Beginning signomial solve.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.181 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.21 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.405 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.335 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.188 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.195 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.156 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.233 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.196 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.175 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.184 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.212 seconds.
# Using solver 'mosek_cli'
# Solving for 252 variables.
# Solving took 0.199 seconds.
# Solving took 13 GP solves and 6.92 seconds.
# Warning: Constraint [2*h_{t_8}_Engine/EnginePerformance/ThrustPerformance_(0,) [J/kg]... >= 2*h_{8}_Engine/EnginePerformance/ThrustPerformance_(0,) + u_{8}_Engine/EnginePerformance/ThrustPerfo...] is not tight because the left hand side evaluated to 599797.382036 joule / kilogram but the right hand side evaluated to 599798.760465 meter ** 2 / second ** 2 (Allowable error: 0.0001%, Actual error: 0.00023%)
#
# Warning: Constraint [2*h_{t_8}_Engine/EnginePerformance/ThrustPerformance_(1,) [J/kg]... >= 2*h_{8}_Engine/EnginePerformance/ThrustPerformance_(1,) + u_{8}_Engine/EnginePerformance/ThrustPerfo...] is not tight because the left hand side evaluated to 599797.382036 joule / kilogram but the right hand side evaluated to 599798.760465 meter ** 2 / second ** 2 (Allowable error: 0.0001%, Actual error: 0.00023%)
#
# Warning: Constraint [F_{6}_Engine/EnginePerformance/ThrustPerformance_(0,) + F_{8}_Engine/EnginePerformance/ThrustPerform... >= F_Engine/EnginePerformance/ThrustPerformance_(0,) [N]...] is not tight because the left hand side evaluated to 24184.3679078 newton but the right hand side evaluated to 24184.0837624 newton (Allowable error: 0.0001%, Actual error: 0.0012%)
#
# Warning: Constraint [F_{6}_Engine/EnginePerformance/ThrustPerformance_(1,) + F_{8}_Engine/EnginePerformance/ThrustPerform... >= F_Engine/EnginePerformance/ThrustPerformance_(1,) [N]...] is not tight because the left hand side evaluated to 26232.5107336 newton but the right hand side evaluated to 26232.3851273 newton (Allowable error: 0.0001%, Actual error: 0.00048%)
#
# Warning: Constraint [-C_{p_{fuel}_Engine/Combustor*T_{t_f}_Engine/Combustor*f_Engine/EnginePerformance/CombustorPerforman... <= \eta_{B}_Engine/Combustor*f_Engine/EnginePerformance/CombustorPerformance_(0,)*h_{f}_Engine/Combusto...] is not tight because the left hand side evaluated to 729580.379426 joule / kilogram but the right hand side evaluated to 0.729593818868 megajoule / kilogram (Allowable error: 0.0001%, Actual error: 0.00075%)
#
# Warning: Constraint [-C_{p_{fuel}_Engine/Combustor*T_{t_f}_Engine/Combustor*f_Engine/EnginePerformance/CombustorPerforman... <= \eta_{B}_Engine/Combustor*f_Engine/EnginePerformance/CombustorPerformance_(1,)*h_{f}_Engine/Combusto...] is not tight because the left hand side evaluated to 820828.787967 joule / kilogram but the right hand side evaluated to 0.820834057637 megajoule / kilogram (Allowable error: 0.0001%, Actual error: 0.00027%)
#
# Warning: Constraint [-\alpha_c_Engine/Combustor*h_{t_4}_Engine/EnginePerformance/CombustorPerformance_(0,) + \alpha_c_Eng... >= fp1_Engine/EnginePerformance/CombustorPerformance_(0,)*h_{t_{4.1}}_Engine/EnginePerformance/Combusto...] is not tight because the left hand side evaluated to 1474011.95517 joule / kilogram but the right hand side evaluated to 1474018.45204 joule / kilogram (Allowable error: 0.0001%, Actual error: 0.00036%)
#
# Warning: Constraint [-\alpha_c_Engine/Combustor*h_{t_4}_Engine/EnginePerformance/CombustorPerformance_(1,) + \alpha_c_Eng... >= fp1_Engine/EnginePerformance/CombustorPerformance_(1,)*h_{t_{4.1}}_Engine/EnginePerformance/Combusto...] is not tight because the left hand side evaluated to 1570523.0765 joule / kilogram but the right hand side evaluated to 1570516.87046 joule / kilogram (Allowable error: 0.0001%, Actual error: 0.00033%)
#
# Warning: Constraint [-M_{takeoff}_Engine/EngineConstants*\eta_{HPshaft}_Engine/Turbine*f_Engine/EnginePerformance/Combust... >= -h_{t_{2.5}}_Engine/EnginePerformance/CompressorPerformance_(0,) + h_{t_3}_Engine/EnginePerformance/...] is not tight because the left hand side evaluated to 364265.736142 joule / kilogram but the right hand side evaluated to 364259.451772 joule / kilogram (Allowable error: 0.0001%, Actual error: 0.00036%)
#
# Warning: Constraint [-M_{takeoff}_Engine/EngineConstants*\eta_{HPshaft}_Engine/Turbine*f_Engine/EnginePerformance/Combust... >= -h_{t_{2.5}}_Engine/EnginePerformance/CompressorPerformance_(1,) + h_{t_3}_Engine/EnginePerformance/...] is not tight because the left hand side evaluated to 388112.843434 joule / kilogram but the right hand side evaluated to 371395.827177 joule / kilogram (Allowable error: 0.0001%, Actual error: 0.91%)

# %%
#print sol.summary()
print sol('\\pi_{hc_D}')
print sol('\\pi_{lc_D}')
print sol('\\pi_{f_D}')
print sol.summary()
# Out:
# 13.2535441542 dimensionless
# 2.0956586597 dimensionless
# 1.88346638331 dimensionless
#
# Cost
# ----
#  7.708 [1/hr]
#
# Free Variables
# --------------
#                   | Engine
#        W_{engine} : 2.32e+04                [N]     Weight of a Single Turbofan Engine
#           d_{LPC} : 0.4485                  [m]     LPC Diameter
#             d_{f} : 1.59                    [m]     Fan Diameter
#          F_{spec} : [ 2.42e+04  2.62e+04 ]  [N]     Specified Total Thrust
#               OPR : [ 31        32       ]          Overall Pressure Ratio
#
#                   | Engine/EnginePerformance/CombustorPerformance
#            M_{4a} : [ 0.103     0.103    ]          User Specified Station 4a Mach #
#            P_{4a} : [ 1.04e+03  1.08e+03 ]  [kPa]   Static Pressure at Station 4a (4a)
#           P_{t_4} : [ 1.04e+03  1.07e+03 ]  [kPa]   Stagnation Pressure at the Combustor Exit (4)
#       P_{t_{4.1}} : [ 1.04e+03  1.08e+03 ]  [kPa]   Stagnation Pressure at the Turbine Inlet (4.1)
#           T_{4.1} : [ 1.19e+03  1.27e+03 ]  [K]     Static Temperature at the Turbine Inlet (4.1)
#           T_{t_4} : [ 1.32e+03  1.41e+03 ]  [K]     Combustor Exit (Station 4) Stagnation Temperature
#       T_{t_{4.1}} : [ 1.19e+03  1.27e+03 ]  [K]     Stagnation Temperature at the Turbine Inlet (4.1)
#                 f : [ 0.0182    0.0205   ]          Fuel Air Mass Flow Fraction
#               fp1 : [ 1.02      1.02     ]          f + 1
#           h_{t_4} : [ 1.61e+06  1.72e+06 ]  [J/kg]  Stagnation Enthalpy at the Combustor Exit (4)
#       h_{t_{4.1}} : [ 1.45e+06  1.54e+06 ]  [J/kg]  Stagnation Enthalpy at the Turbine Inlet (4.1)
#               u_c : [ 0.723     0.747    ]  [m/s]   Cooling Airflow Speed at Station 4a
#           u_{4.1} : [ 3.12      3.23     ]  [m/s]   Flow Velocity at Station 4.1
#            u_{4a} : [ 72.3      74.7     ]  [m/s]   Flow Velocity at Station 4a
#
#                   | Engine/EnginePerformance/CompressorPerformance
#         P_{T_{2}} : [ 35.6      35.6     ]  [kPa]   Stagnation Pressure at the Fan Inlet (2)
#           P_{t_0} : [ 36.4      36.4     ]  [kPa]   Free Stream Stagnation Pressure
#           P_{t_3} : [ 1.1e+03   1.14e+03 ]  [kPa]   Stagnation Pressure at the HPC Exit (3)
#           P_{t_7} : [ 64.2      64.2     ]  [kPa]   Stagnation Pressure at the Fan Nozzle Exit (7)
#       P_{t_{1.8}} : [ 35.6      35.6     ]  [kPa]   Stagnation Pressure at the Diffuser Exit (1.8)
#       P_{t_{2.1}} : [ 65.5      65.5     ]  [kPa]   Stagnation Pressure at the Fan Exit (2.1)
#       P_{t_{2.5}} : [ 148       148      ]  [kPa]   Stagnation Pressure at the LPC Exit (2.5)
#         T_{T_{2}} : [ 246       246      ]  [K]     Stagnation Temperature at the Fan Inlet (2)
#           T_{t_0} : [ 246       246      ]  [K]     Free Stream Stagnation Temperature
#           T_{t_3} : [ 680       687      ]  [K]     Stagnation Temperature at the HPC Exit (3)
#           T_{t_7} : [ 298       298      ]  [K]     Stagnation Temperature at the Fan Nozzle Exit (7)
#       T_{t_{1.8}} : [ 246       246      ]  [K]     Stagnation Temperature at the Diffuser Exit (1.8)
#       T_{t_{2.1}} : [ 298       298      ]  [K]     Stagnation Temperature at the Fan Exit (2.1)
#       T_{t_{2.5}} : [ 380       380      ]  [K]     Stagnation Temperature at the LPC Exit (2.5)
#           \pi_{f} : [ 1.84      1.84     ]          Fan Pressure Ratio
#          \pi_{hc} : [ 7.45      7.7      ]          HPC Pressure Ratio
#          \pi_{lc} : [ 2.26      2.26     ]          LPC Pressure Ratio
#                c1 : [ 1.13      1.13     ]          Constant in Stagnation Eqn
#         h_{T_{2}} : [ 2.47e+05  2.47e+05 ]  [J/kg]  Stagnation Enthalpy at the Fan Inlet (2)
#           h_{t_0} : [ 2.47e+05  2.47e+05 ]  [J/kg]  Free Stream Stagnation Enthalpy
#           h_{t_3} : [ 7.48e+05  7.55e+05 ]  [J/kg]  Stagnation Enthalpy at the HPC Exit (3)
#           h_{t_7} : [ 2.99e+05  2.99e+05 ]  [J/kg]  Stagnation Enthalpy at the Fan Nozzle Exit (7)
#       h_{t_{1.8}} : [ 2.47e+05  2.47e+05 ]  [J/kg]  Stagnation Enthalpy at the Diffuser Exit (1.8)
#       h_{t_{2.1}} : [ 2.99e+05  2.99e+05 ]  [J/kg]  Stagnation Enthalpy at the Fan Exit (2.1)
#       h_{t_{2.5}} : [ 3.83e+05  3.83e+05 ]  [J/kg]  Stagnation Enthalpy at the LPC Exit (2.5)
#        hold_{2.5} : [ 1.06      1.06     ]          1+(gamma-1)/2 * M_2.5**2
#          hold_{2} : [ 1.07      1.07     ]          1+(gamma-1)/2 * M_2**2
#
#                   | Engine/EnginePerformance/FanMapPerformance
#             N_{f} : [ 1.02      1.02     ]          Fan Speed
#             m_{f} : [ 352       352      ]  [kg/s]  Fan Corrected Mass Flow
#        m_{tild_f} : [ 0.946     0.946    ]          Fan Normalized Mass Flow
#
#                   | Engine/EnginePerformance/HPCMapPerformance
#             N_{2} : [ 0.909     0.914    ]          HPC Speed
#            m_{hc} : [ 20.6      20.6     ]  [kg/s]  HPC Corrected Mass Flow
#     m_{tild_{hc}} : [ 0.656     0.656    ]          HPC Normalized Mass Flow
#
#                   | Engine/EnginePerformance/LPCMapPerformance
#             N_{1} : [ 1.02      1.02     ]          LPC Speed
#            m_{lc} : [ 69        69       ]  [kg/s]  LPC Corrected Mass Flow
#       m_{tild_lc} : [ 1.11      1.11     ]          LPC Normalized Mass Flow
#
#                   | Engine/EnginePerformance/SizingPerformance
#               M_2 : [ 0.6       0.6      ]          Fan Face/LPC Face Axial Mach Number
#               M_5 : [ 0.512     0.476    ]          Station 5 Mach Number
#               M_7 : [ 0.691     0.691    ]          Station 7 Mach Number
#           M_{2.5} : [ 0.6       0.6      ]          HPC Face Axial Mach Number
#           P_{2.5} : [ 117       117      ]  [kPa]   Static Air Pressure at HPC Face
#             P_{2} : [ 28        28       ]  [kPa]   Air Static Pressure at Fan Face
#             P_{5} : [ 30.2      34       ]  [kPa]   Core Exhaust Static Pressure (5)
#             P_{7} : [ 38        38       ]  [kPa]   Fan Exhaust Static Pressure (7)
#           T_{2.5} : [ 358       358      ]  [K]     Static Air Temperature at HPC Face
#             T_{2} : [ 230       230      ]  [K]     Air Static Temperature at Fan Face
#             T_{5} : [ 434       474      ]  [K]     Static Temperature at the Turbine Nozzle Exit (5)
#             T_{7} : [ 257       257      ]  [K]     Static Temperature at the Fan Nozzle Exit (7)
#            \rho_5 : [ 0.242     0.25     ]  [kg/m³] Air Static Density at Core Exhaust Exit (5)
#            \rho_7 : [ 0.515     0.515    ]  [kg/m³] Air Static Density at Fam Exhaust Exit (7)
#        \rho_{2.5} : [ 1.14      1.14     ]  [kg/m³] Static Air Density at HPC Face
#          \rho_{2} : [ 0.424     0.424    ]  [kg/m³] Air Static Density at Fan Face
#             a_{5} : [ 416       434      ]  [m/s]   Speed of Sound at Station 5
#             a_{7} : [ 321       321      ]  [m/s]   Speed of Sound at Station 7
#           h_{2.5} : [ 3.93e+05  3.93e+05 ]  [J/kg]  Static Enthalpy at the LPC Exit (2.5)
#             h_{2} : [ 2.31e+05  2.31e+05 ]  [J/kg]  Static Enthalpy at the Fan Inlet (2)
#         m_{total} : [ 174       174      ]  [kg/s]  Total Engine Mass Flux
#           u_{2.5} : [ 228       228      ]  [m/s]   Air Speed at HPC Face
#             u_{2} : [ 175       175      ]  [m/s]   Air Speed at Fan Face
#             u_{5} : [ 213       207      ]  [m/s]   Station 5 Exhaust Velocity
#             u_{7} : [ 222       222      ]  [m/s]   Station 7 Exhaust Velocity
#
#                   | Engine/EnginePerformance/ThrustPerformance
#                 F : [ 2.42e+04  2.62e+04 ]  [N]     Total Thrust
#             F_{6} : [ 4.37e+03  6.42e+03 ]  [N]     Core Thrust
#             F_{8} : [ 1.98e+04  1.98e+04 ]  [N]     Fan Thrust
#            F_{sp} : [ 0.509     0.552    ]          Specific Net Thrust
#            I_{sp} : [ 5.16e+03  4.97e+03 ]  [s]     Specific Impulse
#             P_{6} : [ 23.8      23.8     ]  [kPa]   Core Exhaust Static Pressure
#             P_{8} : [ 23.8      23.8     ]  [kPa]   Fan Exhaust Static Pressure
#           P_{t_6} : [ 45.7      56       ]  [kPa]   Core Exhaust Stagnation Pressure
#           P_{t_8} : [ 64.2      64.2     ]  [kPa]   Fan Exhaust Stagnation Pressure
#              TSFC : [ 0.698     0.724    ]  [1/hr]  Thrust Specific Fuel Consumption
#             T_{6} : [ 406       429      ]  [K]     Core Exhaust Static Temperature (6)
#             T_{8} : [ 225       225      ]  [K]     Fan Exhaust Sttic Temperature (8)
#           T_{t_6} : [ 487       545      ]  [K]     Core Exhaust Stagnation Temperature (6)
#           T_{t_8} : [ 298       298      ]  [K]     Fan Exhaust Stagnation Temperature (8)
#            \alpha : [ 5.1       5.1      ]          By Pass Ratio
#       \alpha_{+1} : [ 6.1       6.1      ]          1 plus BPR
#               h_6 : [ 4.18e+05  4.42e+05 ]  [J/kg]  Core Exhasut Static Enthalpy
#             h_{8} : [ 2.26e+05  2.26e+05 ]  [J/kg]  Fan Exhasut Static Enthalpy
#           h_{t_6} : [ 5.01e+05  5.6e+05  ]  [J/kg]  Core Exhaust Stagnation Enthalpy
#           h_{t_8} : [ 3e+05     3e+05    ]  [J/kg]  Fan Exhaust Stagnation Enthalpy
#              hold : [ 6.1       6.1      ]          unecessary hold var
#          m_{core} : [ 26.3      26.3     ]  [kg/s]  Core Mass Flow
#           m_{fan} : [ 134       134      ]  [kg/s]  Fan Mass Flow
#             u_{6} : [ 408       487      ]  [m/s]   Core Exhaust Velocity
#             u_{8} : [ 384       384      ]  [m/s]   Fan Exhaust Velocity
#
#                   | Engine/EnginePerformance/TurbinePerformance
#           P_{t_5} : [ 45.7      56       ]  [kPa]   Stagnation Pressure at the Turbine Nozzle Exit (5)
#       P_{t_{4.5}} : [ 283       292      ]  [kPa]   Stagnation Pressure at the HPT Exit (4.5)
#       P_{t_{4.9}} : [ 46.6      57.1     ]  [kPa]   Stagnation Pressure at the HPTExit (49)
#           T_{t_5} : [ 487       545      ]  [K]     Stagnation Temperature at the Turbine Nozzle Exit (5)
#       T_{t_{4.5}} : [ 829       882      ]  [K]     Stagnation Temperature at the HPT Exit (4.5)
#       T_{t_{4.9}} : [ 487       545      ]  [K]     Stagnation Temperature at the HPT Exit (49)
#         \pi_{HPT} : [ 0.27      0.27     ]          HPT Pressure Ratio
#         \pi_{LPT} : [ 0.165     0.196    ]          LPT Pressure Ratio
#           h_{t_5} : [ 5.77e+05  6.45e+05 ]  [J/kg]  Stagnation Enthalpy at the Turbine Nozzle Exit (5)
#       h_{t_{4.5}} : [ 1.06e+06  1.13e+06 ]  [J/kg]  Stagnation Enthalpy at the HPT Exit (4.5)
#       h_{t_{4.9}} : [ 5.77e+05  6.45e+05 ]  [J/kg]  Stagnation Enthalpy at the HPT Exit (49)
#
#                   | Engine/FanMap
# \bar{m}_{fan_{D}} : 372.5                   [kg/s]  Fan On-Design Corrected Mass Flow
#         \pi_{f_D} : 1.883                           On-Design Pressure Ratio
#
#                   | Engine/HPCMap
#        \pi_{hc_D} : 13.25                           HPC On-Design Pressure Ratio
#          m_{hc_D} : 31.49                   [kg/s]  On Design HPC Corrected Mass Flow
#
#                   | Engine/LPCMap
#        \pi_{lc_D} : 2.096                           LPC On-Design Pressure Ratio
#          m_{lc_D} : 61.98                   [kg/s]  On Design LPC Corrected Mass Flow
#
#                   | Engine/Sizing
#           A_{2.5} : 0.1011                  [m²]    HPC Area
#             A_{2} : 1.807                   [m²]    Fan Area
#             A_{5} : 0.4963                  [m²]    Core Exhaust Nozzle Area
#             A_{7} : 1.174                   [m²]    Fan Exhaust Nozzle Area
#         m_{coreD} : 44.64                   [kg/s]  Estimated on Design Mass Flow
#           m_{htD} : 5.04                    [kg/s]  Design HPT Corrected Mass Flow (see B.225)
#           m_{ltD} : 15.56                   [kg/s]  Design LPT Corrected Mass Flow (see B.226)
#
#                   | TestState
#                 M : [ 0.8       0.8      ]          Mach Number
#           P_{atm} : [ 23.8      23.8     ]  [kPa]   air pressure
#           T_{atm} : [ 218       218      ]  [K]     air temperature
#                 V : [ 460       460      ]  [kt]    Aircraft Flight Speed
#                 a : [ 296       296      ]  [m/s]   Speed of Sound
#
# Most Sensitive
# --------------
#                | Engine/Combustor
#    C_{p_{fuel} : +2    Specific Heat Capacity of Kerosene (~Jet Fuel)
#       \alpha_c : +1.5  Total Cooling Flow Bypass Ratio
#      hold_{4a} : -1.2  1+(gamma-1)/2 * M_4a**2
#
#                | Engine/EngineConstants
#    M_{takeoff} : -1.5  1 Minus Percent mass flow loss for de-ice, pressurization, etc.
#
#                | Engine/Turbine
# \eta_{HPshaft} : -1.4  Power Transmission Efficiency of High Pressure Shaft, Smears in Losses for Electrical Power

# %%
Sankey(m).sorted_by("constraints", 4)
# Out:
# Ⓐ adds +0.16 to the overall sensitivity of T_{t_0}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓐ is T_{t_0}_Engine/EnginePerformance/CompressorPerformance_(0,) = T_{atm}_TestState_(0,)*c1_Engine/EnginePerformance/CompressorPerformance_(0,)
#
# Ⓑ adds -3.21 to the overall sensitivity of T_{t_0}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓑ is h_{t_0}_Engine/EnginePerformance/CompressorPerformance_(0,) = C_{p_{air}_Engine/Compressor*T_{t_0}_Engine/EnginePerformance/CompressorPerformance_(0,)
#
# Ⓒ adds +3.05 to the overall sensitivity of T_{t_0}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓒ is T_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,) = T_{t_0}_Engine/EnginePerformance/CompressorPerformance_(0,)
#
# Ⓒ adds -3.05 to the overall sensitivity of T_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓒ is T_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,) = T_{t_0}_Engine/EnginePerformance/CompressorPerformance_(0,)
#
# Ⓓ adds +3.11 to the overall sensitivity of T_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓓ is T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,) = T_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,)
#
# Ⓓ adds -3.11 to the overall sensitivity of T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓓ is T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,) = T_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,)
#
# Ⓔ adds +2.48 to the overall sensitivity of T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓔ is T_{t_{2.1}}_Engine/EnginePerformance/CompressorPerformance_(0,) = T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)*\pi_{f}_Engine/EnginePerformance/CompressorPerformance_(0,)**0.32
#
# Ⓕ adds +0.581 to the overall sensitivity of T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓕ is T_{t_{2.5}}_Engine/EnginePerformance/CompressorPerformance_(0,) = T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)*\pi_{f}_Engine/EnginePerformance/CompressorPerformance_(0,)**0.31*\pi_{lc}_Engine/EnginePerformance/CompressorPerformance_(0,)**0.31
#
# Ⓖ adds -7.24e-12 to the overall sensitivity of T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓖ is m_{f}_Engine/EnginePerformance/FanMapPerformance_(0,) = P_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)**-1*P_{ref}_Engine/EngineConstants*T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)**0.5*T_{ref}_Engine/EngineConstants**-0.5*m_{fan}_Engine/EnginePerformance/ThrustPerformance_(0,)
#
# Ⓗ adds +0.0578 to the overall sensitivity of T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓗ is m_{lc}_Engine/EnginePerformance/LPCMapPerformance_(0,) = P_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)**-1*P_{ref}_Engine/EngineConstants*T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)**0.5*T_{ref}_Engine/EngineConstants**-0.5*m_{core}_Engine/EnginePerformance/ThrustPerformance_(0,)
#
# Ⓘ adds -0.0154 to the overall sensitivity of T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓘ is T_{2}_Engine/EnginePerformance/SizingPerformance_(0,) = T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)*hold_{2}_Engine/EnginePerformance/CompressorPerformance_(0,)**-1
#
# Ⓙ adds -0.0578 to the overall sensitivity of T_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,)
# Ⓙ is m_{ltD}_Engine/Sizing = M_{takeoff}_Engine/EngineConstants*P_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,)*P_{t_{4.5}}_Engine/EnginePerformance/TurbinePerformance_(0,)**-1*T_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,)**-0.5*T_{t_{4.5}}_Engine/EnginePerformance/TurbinePerformance_(0,)**0.5*fp1_Engine/EnginePerformance/CombustorPerformance_(0,)*m_{lc}_Engine/EnginePerformance/LPCMapPerformance_(0,)
# SankeyWidget(layout=Layout(height=u'400', width=u'900'), links=[{'color': '#cfcfcf', 'source': 'T_{t_0}_Engine/EnginePerformance/CompressorPerformance_(0,)', 'target': 'Model', 'value': 3.20789e-05}, {'color': '#FA3333', 'source': 'Model', 'target': u'\u24ba', 'value': 2.481782}, {'color': '#59ade4', 'source': 'Model', 'target': u'\u24bf', 'value': 0.0578353}, {'color': '#FA3333', 'source': 'Model', 'target': u'\u24bb', 'value': 0.5813576}, {'color': '#59ade4', 'source': 'Model', 'target': u'\u24b7', 'value': 3.20789}, {'color': '#cfcfcf', 'source': 'Model', 'target': u'\u24b9', 'value': 3.20789e-05}, {'color': '#cfcfcf', 'source': 'T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)', 'target': 'Model', 'value': 3.20789e-05}, {'color': '#cfcfcf', 'source': 'Model', 'target': u'\u24b8', 'value': 3.20789e-05}, {'color': '#59ade4', 'source': 'Model', 'target': u'\u24be', 'value': 0.01538903}, {'color': '#FA3333', 'source': 'Model', 'target': u'\u24b6', 'value': 0.1601398}, {'color': '#FA3333', 'source': 'Model', 'target': u'\u24bd', 'value': 0.0578353}, {'color': '#cfcfcf', 'source': 'T_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,)', 'target': 'Model', 'value': 3.20789e-05}, {'color': '#cfcfcf', 'source': 'Model', 'target': u'\u24bc', 'value': 3.20789e-05}], margins={'top': 0, 'right': 55, 'left': 120, 'bottom': 0}, nodes=[{'id': 'T_{t_0}_Engine/EnginePerformance/CompressorPerformance_(0,)', 'title': u'T_{t_0}_(0,) [K] \u2777'}, {'id': 'T_{t_{1.8}}_Engine/EnginePerformance/CompressorPerformance_(0,)', 'title': u'T_{t_{1.8}}_(0,) [K] \u2778'}, {'id': 'T_{T_{2}}_Engine/EnginePerformance/CompressorPerformance_(0,)', 'title': u'T_{T_{2}}_(0,) [K] \u2776'}, {'id': u'\u24b9', 'title': u'\u24b9\u2009\u2776=\u2778'}, {'id': u'\u24b8', 'title': u'\u24b8\u2009\u2778=\u2777'}, {'id': u'\u24bc'}, {'id': u'\u24b7'}, {'id': u'\u24b6'}, {'id': 'Model'}, {'id': u'\u24ba'}, {'id': u'\u24bd'}, {'id': u'\u24bb'}, {'id': u'\u24bf'}, {'id': u'\u24be'}])
